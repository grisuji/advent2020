# %%
import re
a="class: 1-3 or 5-7"

re.findall("\w+: (\d+)-(\d+) or (\d+)-(\d+)",a)
# Out:
# [('1', '3', '5', '7')]

# %%
import numpy as np
import re

classes=[]
def read_data(file):
    section = 1
    with open(file,'r') as f:
        for l in f:
            ll = l[:-1]
            if ll == "":
                continue
            if l == "your ticket:"
                section = 2
                continue
            f l == "nearby tickets:"
                section = 3
                continue
            if section == 1:
                n1, x1, n2, x2 = re.findall("\w+: (\d+)-(\d+) or (\d+)-(\d+)",ll)[0]
                classes.append((n1,x1))
                classes.append((n2,x2))
            if se
                
    return start, busids 
tstart, tbusids = read_data("t.txt")
istart, ibusids = read_data("i.txt")
